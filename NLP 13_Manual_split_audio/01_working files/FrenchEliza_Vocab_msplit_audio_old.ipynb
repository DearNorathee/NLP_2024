# %%
from pydub import AudioSegment
from pydub.silence import split_on_silence
from pydub.playback import play
from pydub.silence import detect_nonsilent
from playsound import playsound
import py_string_tool as pst
from typing import Union,Dict,Tuple, List, Literal
import python_wizard as pw
import video_toolkit as vt

# approx speed of doing manual audio: 30 min/ 10 audio

# %%
alarm_path = r"C:\C_Music\Sound Effect positive-logo-opener.mp3"
filepath = r"C:\C_Video\Learn French\100 questions et réponses en français A1 à C1\100 questions et réponses en français A1 à C1.mp4"
OUTPUT_FOLDER:str = r"C:\C_Video_Python\Learn French\100 questions et réponses en français A1 à C1\Question and Answer Part_YoutubeSub_manual_edit"

# %%
# took about 2 min(for 3 hr audio)
audio = AudioSegment.from_file(filepath)

# %%
start_time = 35 * 1000  # Start at 35 seconds
end_time = (1*60 + 35) * 1000    # End at 1 minute and 35 seconds

# %%
time_in_ms:int = 28_000
vt.ms_to_time_text(time_in_ms)
# Out:
# '0.28'

# %%
time_in_str:str = "19.07"
vt.text_to_milisecond(time_in_str)
print(f"{vt.text_to_milisecond(time_in_str):_}")
print(f"{vt.text_to_milisecond(time_in_str)+3000:_}")
# Out:
# 1_147_000
# 1_150_000

# %%
output_names: dict[int|float, str] = {
    49:  "fr_youtube01_049_j'ai des enfants. Et j'ai lu cette liste à ma mère_manual.wav",
    72:  "fr_youtube01_072_On se voit pour Noël, on fête Noël ensemble_manual.wav",
    73:  "fr_youtube01_073_parfois le jour de l'an aussi, mais pas toujours_manual.wav",
    136:  "fr_youtube01_136_parce que j'adore la civilisation égyptienne_manual.wav",
    178:  "fr_youtube01_178_Il y a beaucoup de choses que j'aime cuisiner_manual.wav",
    180:  "fr_youtube01_180_Je pense que j'aime bien faire de la pâtisserie en général parce_manual.wav",
    237:  "fr_youtube01_237_Au lycée, un peu moins, parce que ça devenait un peu plus compliqué en maths, physique, sciences, etc_manual.wav",
    245:  "fr_youtube01_245_J'étais timide quand j'étais assez jeune et en grandissant_manual.wav",

    # Apr, 14, 2025

    147:  "fr_youtube01_147_en liberté, ça a été un moment très, très, très intense_manual.wav",
    173:  "fr_youtube01_173_J'en ai déjà fait, mais j'aimerais bien recommencer un peu plus sérieusement_manual.wav",
    174:  "fr_youtube01_174_Si j'avais le temps, parce que je fais déjà beaucoup d'autres choses et_manual.wav",
    175:  "fr_youtube01_175_c'est compliqué de prendre le temps_manual.wav",

    230:  "fr_youtube01_230_J'ai eu beaucoup de bons profs dans ma scolarité, mais la première_manual.wav",
    264:  "fr_youtube01_264_c'est-à-dire que je range pas les choses_manual.wav",
    265:  "fr_youtube01_265_et j'arrive pas à garder la maison rangée plus de deux jours_manual.wav",
    269:  "fr_youtube01_269_Peut-être avoir un peu plus confiance en moi dans certaines situations_manual.wav",
    280:  "fr_youtube01_280_Je pense que les réseaux sociaux, on peut en faire le meilleur comme on peut en faire le pire_manual.wav",

    # Jun, 7, 2025
    306:  "fr_youtube01_306_Ça va être un peu philosophique, mais un des meilleurs conseils qu'on m'ait donnés_manual.wav",
    307:  "fr_youtube01_307_c'est qu'il y avait beaucoup de choses qu'on peut pas contrôler dans la vie_manual.wav",
    308:  "fr_youtube01_308_mais ce qu'on peut essayer de contrôler, c'est son calme intérieur, donc sa paix intérieure._manual.wav",


    }

# %%
# cut 6
manual_edit: dict[int|float, list[int]] = {
    49:  (172_500 , 176_000),
    72:  (239_000 , 245_000),
    73:  (245_000 , 248_000),
    136:  (481_000 , 486_500),
    178:  (643_000 , 646_000),
    180:  (647_000 , 651_300),
    237: (867_000 , 874_100),
    245: (896_000 , 902_000),


    # Apr, 15, 2025
    147: (526_000 , 530_900),
    173: (623_500 , 629_000),
    174: (629_000 , 633_500),
    175: (633_500 , 635_500),


    230: (842_300 , 847_000),

    264: (972_700 , 975_500),
    265: (975_500 , 980_500),
    269: (994_700 , 999_200),

    280: (1_037_000 , 1_044_500),

    306: (1_140_000 , 1_147_000),
    307:  (1_147_000 , 1_151_500),
    308:  (1_151_500 , 1_181_500),
    # 6.2:  (99_000 , 104_000),
    # 7:  (112_000 , 114_000),
    # 8:  (126_000 , 129_000),
    # 9:  (142_000 , 145_000),

    
    }
manual_index = max(manual_edit.keys())

# manual_index = 230

print(manual_index)
# Out:
# 307

# %%
# if your index is higher than it would crash your kernel
if manual_edit[manual_index][0] > manual_edit[manual_index][1]:
    raise Exception(f"check your index make sure first index is less than second index")

display_audio = audio[manual_edit[manual_index][0] : manual_edit[manual_index][1]]
# play(display_audio)
display_audio
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# play(chunks[audio_index])
vt.export_audio(audio, manual_edit, output_names,output_folder=OUTPUT_FOLDER)

# plot_loudness(segment)
# Out:
# 100%|██████████| 17/17 [00:01<00:00,  8.62it/s]
