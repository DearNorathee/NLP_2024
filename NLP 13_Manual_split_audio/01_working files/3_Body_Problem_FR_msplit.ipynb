# %%
from pydub import AudioSegment
from pydub.silence import split_on_silence
from pydub.playback import play
from pydub.silence import detect_nonsilent
from playsound import playsound
import py_string_tool as pst
from typing import Union,Dict,Tuple, List, Literal
import python_wizard as pw
import video_toolkit as vt

# approx speed of doing manual audio: 30 min/ 10 audio

# %%
alarm_path = r"C:\C_Music\Sound Effect positive-logo-opener.mp3"
filepath = r"C:\C_Video_Python\3 Body Problem\3 Body Problem Season 01\Season 01 Audio\French\3 Body Problem_S01E03_4_FR.mp3"
OUTPUT_FOLDER:str = r"C:\C_Video_Python\3 Body Problem\3 Body Problem Season 01\Season 01 Splitted Audio\French\3 Body Problem_S01E03_FR_FR_msplit"

# %%
# took about 2 min(for 3 hr audio)
audio = AudioSegment.from_file(filepath)

# %%
start_time = 35 * 1000  # Start at 35 seconds
end_time = (1*60 + 35) * 1000    # End at 1 minute and 35 seconds

# %%
time_in_ms:int = 28_000
vt.ms_to_time_text(time_in_ms)
# Out:
# '0.28'

# %%
time_in_str:str = "40.35"
vt.text_to_milisecond(time_in_str)
print(f"{vt.text_to_milisecond(time_in_str):_}")
print(f"{vt.text_to_milisecond(time_in_str)+3000:_}")
# Out:
# 2_435_000
# 2_438_000

# %%
output_names: dict[int|float, str] = {
    # Mar, 31, 2026

    26:  "3 Body Problem FR_S01E03_026_D'après mon pote du CERN.mp3"
    ,39:  "3 Body Problem FR_S01E03_039_J'en ai vendu un demi–million.mp3"
    ,66:  "3 Body Problem FR_S01E03_066_Je me rappelle plus très bien, mais ça parlait d'accouplement.mp3"
    ,101:  "3 Body Problem FR_S01E03_101_T'as fait une partie.mp3"
    ,105:  "3 Body Problem FR_S01E03_105_J'ai vu un château, je sentais le vent.mp3"
    ,118:  "3 Body Problem FR_S01E03_118_J'ai jamais vu une technologie aussi avancée.mp3"
    ,135:  "3 Body Problem FR_S01E03_135_C'est pas pareil.mp3"
    ,150:  "3 Body Problem FR_S01E03_150_Je vais pas me suicider, c'est ridicule.mp3"
    ,229:  "3 Body Problem FR_S01E03_229_J'ai effectué des mesures approfondies.mp3"
    ,230:  "3 Body Problem FR_S01E03_230_sur la dimension du Soleil et sa luminosité.mp3"
    ,236:  "3 Body Problem FR_S01E03_236_se déplaçant alors que les étoiles restaient fixes.mp3"
    ,238:  "3 Body Problem FR_S01E03_238_est que cette planète fait partie.mp3"
    ,239:  "3 Body Problem FR_S01E03_239_de ce que nous appelons un système à trois corps.mp3"
    ,243:  "3 Body Problem FR_S01E03_243_Cependant, si l'un des deux autres soleils attire brusquement notre planète.mp3"
    ,256:  "3 Body Problem FR_S01E03_256_C'est la seule explication sensée !.mp3"
    ,273:  "3 Body Problem FR_S01E03_273_Sauvez–moi !.mp3"
    ,326:  "3 Body Problem FR_S01E03_326_J'avais prévu de tout ranger avant que tu rentres.mp3"



    # Mar, 31, 2026
    ,704:  "3 Body Problem FR_S01E03_704_Ils deviennent souvent des modèles, des sources d'inspiration des exemples à suivre.mp3"
    ,754:  "3 Body Problem FR_S01E03_754_Aucun ordinateur ne peut prédire le comportement de trois corps de manière permanente.mp3"

    }

# added _manual automatically at the end of the file name
import re
def add_manual(fname: str) -> str:
    low = fname.lower()
    if low.endswith('_manual.wav') or low.endswith('_manual.mp3'):
        return fname
    return re.sub(r'(\.(?:wav|mp3))$', r'_manual\1', fname, flags=re.IGNORECASE)

output_names_adj: dict[int|float, str] = {k: add_manual(v) for k, v in output_names.items()}

# %%
# cut 6
manual_edit: dict[int|float, list[int]] = {
    # Apr 6, 2026
    26: (125_500 , 127_000),
    39: (159_000 , 162_000),
    66: (235_000 , 239_000),
    101: (377_400 , 379_000),
    105: (384_900 , 387_000),
    118: (418_000 , 421_000),
    135: (465_500 , 467_000),
    150: (514_000 , 516_700),
    229: (734_000 , 736_300),
    230: (736_200 , 738_500),
    236: (752_000 , 755_000),
    238: (759_500 , 762_300),
    239: (762_200 , 765_000),
    243: (779_000 , 783_700),
    256: (817_000 , 820_000),
    273: (848_000 , 849_000),
    326: (1_026_000 , 1_029_000),
    
    704: (2_218_200 , 2_223_000),
    754: (2_435_500 , 2_440_000),


    }
manual_index = max(manual_edit.keys())

# manual_index = 10

print(manual_index)
# Out:
# 754

# %%
# if your index is higher than it would crash your kernel
if manual_edit[manual_index][0] > manual_edit[manual_index][1]:
    raise Exception(f"check your index make sure first index is less than second index")

display_audio = audio[manual_edit[manual_index][0] : manual_edit[manual_index][1]]
# play(display_audio)
display_audio
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# play(chunks[audio_index])
vt.export_audio(audio, manual_edit, output_names_adj,output_folder=OUTPUT_FOLDER)

# plot_loudness(segment)
# Out:
# 100%|██████████| 19/19 [00:09<00:00,  2.02it/s]
