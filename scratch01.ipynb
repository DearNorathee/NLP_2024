# %%
import tensorflow as tf
print("Num GPUs Available:", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import tensorflow as tf
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\__init__.py:469
#     467 if hasattr(_current_module, "keras"):
#     468   try:
# --> 469     _keras._load()
#     470   except ImportError:
#     471     pass
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\lazy_loader.py:41, in LazyLoader._load(self)
#      39 """Load the module and insert it into the parent's globals."""
#      40 # Import the target module and insert it into the parent's namespace
# ---> 41 module = importlib.import_module(self.__name__)
#      42 self._parent_module_globals[self._local_name] = module
#      44 # Emit a warning if one was specified
#
# File c:\ProgramData\Anaconda3\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\functional.py:34
#      32 from keras.engine import input_spec
#      33 from keras.engine import node as node_module
# ---> 34 from keras.engine import training as training_lib
#      35 from keras.engine import training_utils
#      36 from keras.saving.saved_model import json_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\training.py:33
#      31 from keras.engine import base_layer
#      32 from keras.engine import base_layer_utils
# ---> 33 from keras.engine import compile_utils
#      34 from keras.engine import data_adapter
#      35 from keras.engine import input_layer as input_layer_module
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\compile_utils.py:24
#      21 import tensorflow.compat.v2 as tf
#      23 from keras import losses as losses_mod
# ---> 24 from keras import metrics as metrics_mod
#      25 from keras.saving.experimental import saving_lib
#      26 from keras.utils import generic_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\metrics\__init__.py:33
#      29 from keras.metrics.base_metric import clone_metrics
#      31 # Metric functions
#      32 # Individual metric classes
# ---> 33 from keras.metrics.metrics import AUC
#      34 from keras.metrics.metrics import Accuracy
#      35 from keras.metrics.metrics import BinaryAccuracy
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\metrics\metrics.py:28
#      25 import numpy as np
#      26 import tensorflow.compat.v2 as tf
# ---> 28 from keras import activations
#      29 from keras import backend
#      30 from keras.dtensor import utils as dtensor_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\activations.py:21
#      17 import sys
#      19 import tensorflow.compat.v2 as tf
# ---> 21 import keras.layers.activation as activation_layers
#      22 from keras import backend
#      23 from keras.utils import generic_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\layers\__init__.py:20
#      17 import tensorflow.compat.v2 as tf
#      19 from keras.engine.base_layer import Layer
# ---> 20 from keras.engine.base_preprocessing_layer import PreprocessingLayer
#      22 # Generic layers.
#      23 from keras.engine.input_layer import Input
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\base_preprocessing_layer.py:21
#      17 import abc
#      19 import tensorflow.compat.v2 as tf
# ---> 21 from keras.engine import data_adapter
#      22 from keras.engine.base_layer import Layer
#      23 from keras.utils import version_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\engine\data_adapter.py:43
#      40 from tensorflow.python.util.tf_export import keras_export
#      42 try:
# ---> 43     import pandas as pd
#      44 except ImportError:
#      45     pd = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\__init__.py:73
#      70 # let init-time option registration happen
#      71 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 73 from pandas.core.api import (
#      74     # dtype
#      75     ArrowDtype,
#      76     Int8Dtype,
#      77     Int16Dtype,
#      78     Int32Dtype,
#      79     Int64Dtype,
#      80     UInt8Dtype,
#      81     UInt16Dtype,
#      82     UInt32Dtype,
#      83     UInt64Dtype,
#      84     Float32Dtype,
#      85     Float64Dtype,
#      86     CategoricalDtype,
#      87     PeriodDtype,
#      88     IntervalDtype,
#      89     DatetimeTZDtype,
#      90     StringDtype,
#      91     BooleanDtype,
#      92     # missing
#      93     NA,
#      94     isna,
#      95     isnull,
#      96     notna,
#      97     notnull,
#      98     # indexes
#      99     Index,
#     100     CategoricalIndex,
#     101     RangeIndex,
#     102     MultiIndex,
#     103     IntervalIndex,
#     104     TimedeltaIndex,
#     105     DatetimeIndex,
#     106     PeriodIndex,
#     107     IndexSlice,
#     108     # tseries
#     109     NaT,
#     110     Period,
#     111     period_range,
#     112     Timedelta,
#     113     timedelta_range,
#     114     Timestamp,
#     115     date_range,
#     116     bdate_range,
#     117     Interval,
#     118     interval_range,
#     119     DateOffset,
#     120     # conversion
#     121     to_numeric,
#     122     to_datetime,
#     123     to_timedelta,
#     124     # misc
#     125     Flags,
#     126     Grouper,
#     127     factorize,
#     128     unique,
#     129     value_counts,
#     130     NamedAgg,
#     131     array,
#     132     Categorical,
#     133     set_eng_float_format,
#     134     Series,
#     135     DataFrame,
#     136 )
#     138 from pandas.core.dtypes.dtypes import SparseDtype
#     140 from pandas.tseries.api import infer_freq
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\api.py:47
#      45 from pandas.core.construction import array
#      46 from pandas.core.flags import Flags
# ---> 47 from pandas.core.groupby import (
#      48     Grouper,
#      49     NamedAgg,
#      50 )
#      51 from pandas.core.indexes.api import (
#      52     CategoricalIndex,
#      53     DatetimeIndex,
#    (...)
#      59     TimedeltaIndex,
#      60 )
#      61 from pandas.core.indexes.datetimes import (
#      62     bdate_range,
#      63     date_range,
#      64 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\__init__.py:1
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#       6 from pandas.core.groupby.groupby import GroupBy
#       7 from pandas.core.groupby.grouper import Grouper
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\generic.py:67
#      59 from pandas.core.apply import (
#      60     GroupByApply,
#      61     maybe_mangle_lambdas,
#    (...)
#      64     warn_alias_replacement,
#      65 )
#      66 import pandas.core.common as com
# ---> 67 from pandas.core.frame import DataFrame
#      68 from pandas.core.groupby import (
#      69     base,
#      70     ops,
#      71 )
#      72 from pandas.core.groupby.groupby import (
#      73     GroupBy,
#      74     GroupByPlot,
#    (...)
#      78     _transform_template,
#      79 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:142
#     135 from pandas.core.arrays.sparse import SparseFrameAccessor
#     136 from pandas.core.construction import (
#     137     ensure_wrapped_if_datetimelike,
#     138     extract_array,
#     139     sanitize_array,
#     140     sanitize_masked_array,
#     141 )
# --> 142 from pandas.core.generic import (
#     143     NDFrame,
#     144     make_doc,
#     145 )
#     146 from pandas.core.indexers import check_key_length
#     147 from pandas.core.indexes.api import (
#     148     DatetimeIndex,
#     149     Index,
#    (...)
#     153     ensure_index_from_sequences,
#     154 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:146
#     137 from pandas.core.dtypes.inference import (
#     138     is_hashable,
#     139     is_nested_list_like,
#     140 )
#     141 from pandas.core.dtypes.missing import (
#     142     isna,
#     143     notna,
#     144 )
# --> 146 from pandas.core import (
#     147     algorithms as algos,
#     148     arraylike,
#     149     common,
#     150     indexing,
#     151     missing,
#     152     nanops,
#     153     sample,
#     154 )
#     155 from pandas.core.array_algos.replace import should_use_regex
#     156 from pandas.core.arrays import ExtensionArray
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:70
#      60 from pandas.core.construction import (
#      61     array as pd_array,
#      62     extract_array,
#      63 )
#      64 from pandas.core.indexers import (
#      65     check_array_indexer,
#      66     is_list_like_indexer,
#      67     is_scalar_indexer,
#      68     length_of_indexer,
#      69 )
# ---> 70 from pandas.core.indexes.api import (
#      71     Index,
#      72     MultiIndex,
#      73 )
#      75 if TYPE_CHECKING:
#      76     from collections.abc import (
#      77         Hashable,
#      78         Sequence,
#      79     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\api.py:20
#      17 from pandas.core.dtypes.cast import find_common_type
#      19 from pandas.core.algorithms import safe_sort
# ---> 20 from pandas.core.indexes.base import (
#      21     Index,
#      22     _new_Index,
#      23     ensure_index,
#      24     ensure_index_from_sequences,
#      25     get_unanimous_names,
#      26 )
#      27 from pandas.core.indexes.category import CategoricalIndex
#      28 from pandas.core.indexes.datetimes import DatetimeIndex
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:28
#      21 import numpy as np
#      23 from pandas._config import (
#      24     get_option,
#      25     using_copy_on_write,
#      26 )
# ---> 28 from pandas._libs import (
#      29     NaT,
#      30     algos as libalgos,
#      31     index as libindex,
#      32     lib,
#      33 )
#      34 from pandas._libs.internals import BlockValuesRefs
#      35 import pandas._libs.join as libjoin
#
# File index.pyx:33, in init pandas._libs.index()
#
# File <frozen importlib._bootstrap>:1044, in _handle_fromlist(module, fromlist, import_, recursive)
#
# SystemError: <built-in function isinstance> returned a result with an error set

# %%
print("yeah")
# Out:
# yeah
